# %% [markdown]
# <a href="https://colab.research.google.com/github/acarjunarju/About-nagarjuna-N/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 1
while i<5:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range (1,5):
  for j in range (i):
    print("*",end="")

  print()
# Out:
# *
# **
# ***
# ****

# %%
u = 6
i = 1

while i < u:
    j = 1
    while j < i:
        print("*", end=" ")
        j += 1
    print()
    i += 1
# Out:
# *
# * *
# * * *
# * * * *

# %%
for i in range (1,10,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range (1,10):
  if i==5:
    break
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range (1,10):
  if i==5:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
for i in range (1,10):
  pass
